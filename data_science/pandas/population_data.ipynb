# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'D:\python_learning_journey\data\2023_Countries_by_Population.csv')
df.head()
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# 1    156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09  1.425671e+09
# 2    840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08  3.399966e+08
# 3    360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08  2.775341e+08
# 4    586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08  2.404857e+08
#
#         pop2030       pop2050        country       area  landAreaKm cca2 cca3  \
# 0  1.514994e+09  1.670491e+09          India  3287590.0   2973190.0   IN  IND
# 1  1.415606e+09  1.312636e+09          China  9706961.0   9424702.9   CN  CHN
# 2  3.521623e+08  3.753920e+08  United States  9372610.0   9147420.0   US  USA
# 3  2.921501e+08  3.172252e+08      Indonesia  1904569.0   1877519.0   ID  IDN
# 4  2.740298e+08  3.678085e+08       Pakistan   881912.0    770880.0   PK  PAK
#
# ...

# %%
df.shape
# Out:
# (234, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   place            234 non-null    int64
#  1   pop1980          234 non-null    float64
#  2   pop2000          234 non-null    float64
#  3   pop2010          234 non-null    float64
#  4   pop2022          234 non-null    float64
#  5   pop2023          234 non-null    float64
#  6   pop2030          234 non-null    float64
#  7   pop2050          234 non-null    float64
#  8   country          234 non-null    object
#  9   area             234 non-null    float64
#  10  landAreaKm       234 non-null    float64
#  11  cca2             233 non-null    object
#  12  cca3             234 non-null    object
#  13  netChange        226 non-null    float64
#  14  growthRate       234 non-null    float64
#  15  worldPercentage  228 non-null    float64
# ...

# %%
df.describe()
# Out:
#             place       pop1980       pop2000       pop2010       pop2022  \
# count  234.000000  2.340000e+02  2.340000e+02  2.340000e+02  2.340000e+02
# mean   439.085470  1.898462e+07  2.626947e+07  2.984524e+07  3.407441e+07
# std    253.295484  8.178519e+07  1.116982e+08  1.242185e+08  1.367664e+08
# min      4.000000  7.330000e+02  6.510000e+02  5.960000e+02  5.100000e+02
# 25%    223.000000  2.296142e+05  3.272420e+05  3.931490e+05  4.197385e+05
# 50%    439.000000  3.141146e+06  4.292907e+06  4.942770e+06  5.559944e+06
# 75%    659.750000  9.826054e+06  1.576230e+07  1.915957e+07  2.247650e+07
# max    894.000000  9.823725e+08  1.264099e+09  1.348191e+09  1.425887e+09
#
#             pop2023       pop2030       pop2050          area    landAreaKm  \
# count  2.340000e+02  2.340000e+02  2.340000e+02  2.340000e+02  2.340000e+02
# mean   3.437442e+07  3.651461e+07  4.148628e+07  5.814500e+05  5.571123e+05
# ...

# %%
df.isnull().sum()
# Out:
# place              0
# pop1980            0
# pop2000            0
# pop2010            0
# pop2022            0
# pop2023            0
# pop2030            0
# pop2050            0
# country            0
# area               0
# landAreaKm         0
# cca2               1
# cca3               0
# netChange          8
# growthRate         0
# worldPercentage    6
# density            0
# densityMi          0
# rank               0
# dtype: int64

# %%
a=df[df.loc[:,'netChange'].isnull()]
a
# Out:
#      place  pop1980  pop2000  pop2010  pop2022  pop2023  pop2030  pop2050  \
# 217    674  21346.0  26823.0  31608.0  33660.0  33642.0  33458.0  32044.0
# 221    585  12252.0  19726.0  18540.0  18055.0  18058.0  17919.0  16689.0
# 227    652   2983.0   7082.0   8988.0  10967.0  10994.0  11113.0  10210.0
# 228    666   6106.0   6274.0   6052.0   5862.0   5840.0   5651.0   5165.0
# 229    500  11452.0   5138.0   4938.0   4390.0   4386.0   4301.0   3781.0
# 230    238   2240.0   3080.0   3187.0   3780.0   3791.0   3869.0   3779.0
# 232    772   1647.0   1666.0   1367.0   1871.0   1893.0   2046.0   2430.0
# 233    336    733.0    651.0    596.0    510.0    518.0    561.0    731.0
#
#                        country      area  landAreaKm cca2 cca3  netChange  \
# 217                 San Marino     61.00       60.00   SM  SMR        NaN
# 221                      Palau    459.00      460.00   PW  PLW        NaN
# 227           Saint Barthelemy     21.00       25.00   BL  BLM        NaN
# ...

# %%
ans=[(a['pop2000']-a['pop1980'])/20,(a['pop2010']-a['pop2000'])/10,(a['pop2022']-a['pop2010'])/12,(a['pop2023']-a['pop2022']),(a['pop2023']-a['pop2030'])/7,(a['pop2050']-a['pop2030'])/20]
ans
# Out:
# [217    273.85
#  221    373.70
#  227    204.95
#  228      8.40
#  229   -315.70
#  230     42.00
#  232      0.95
#  233     -4.10
#  dtype: float64,
#  217    478.5
#  221   -118.6
#  227    190.6
#  228    -22.2
#  229    -20.0
#  230     10.7
#  232    -29.9
#  233     -5.5
#  dtype: float64,
#  217    171.000000
#  221    -40.416667
#  227    164.916667
#  228    -15.833333
#  229    -45.666667
#  230     49.416667
#  232     42.000000
#  233     -7.166667
#  dtype: float64,
#  217   -18.0
#  221     3.0
#  227    27.0
#  228   -22.0
#  229    -4.0
#  230    11.0
#  232    22.0
#  233     8.0
#  dtype: float64,
#  217    26.285714
#  221    19.857143
#  227   -17.000000
#  228    27.000000
#  229    12.142857
#  230   -11.142857
#  232   -21.857143
#  233    -6.142857
#  dtype: float64,
#  217   -70.70
#  221   -61.50
#  227   -45.15
#  228   -24.30
#  229   -26.00
#  230    -4.50
#  232    19.20
#  233     8.50
#  dtype: float64]

# %%
a
# Out:
#      place  pop1980  pop2000  pop2010  pop2022  pop2023  pop2030  pop2050  \
# 217    674  21346.0  26823.0  31608.0  33660.0  33642.0  33458.0  32044.0
# 221    585  12252.0  19726.0  18540.0  18055.0  18058.0  17919.0  16689.0
# 227    652   2983.0   7082.0   8988.0  10967.0  10994.0  11113.0  10210.0
# 228    666   6106.0   6274.0   6052.0   5862.0   5840.0   5651.0   5165.0
# 229    500  11452.0   5138.0   4938.0   4390.0   4386.0   4301.0   3781.0
# 230    238   2240.0   3080.0   3187.0   3780.0   3791.0   3869.0   3779.0
# 232    772   1647.0   1666.0   1367.0   1871.0   1893.0   2046.0   2430.0
# 233    336    733.0    651.0    596.0    510.0    518.0    561.0    731.0
#
#                        country      area  landAreaKm cca2 cca3  netChange  \
# 217                 San Marino     61.00       60.00   SM  SMR        NaN
# 221                      Palau    459.00      460.00   PW  PLW        NaN
# 227           Saint Barthelemy     21.00       25.00   BL  BLM        NaN
# ...

# %%
n=pd.DataFrame(ans)
n
# Out:
#           217         221         227        228         229        230  \
# 0  273.850000  373.700000  204.950000   8.400000 -315.700000  42.000000
# 1  478.500000 -118.600000  190.600000 -22.200000  -20.000000  10.700000
# 2  171.000000  -40.416667  164.916667 -15.833333  -45.666667  49.416667
# 3  -18.000000    3.000000   27.000000 -22.000000   -4.000000  11.000000
# 4   26.285714   19.857143  -17.000000  27.000000   12.142857 -11.142857
# 5  -70.700000  -61.500000  -45.150000 -24.300000  -26.000000  -4.500000
#
#          232       233
# 0   0.950000 -4.100000
# 1 -29.900000 -5.500000
# 2  42.000000 -7.166667
# 3  22.000000  8.000000
# 4 -21.857143 -6.142857
# 5  19.200000  8.500000

# %%
n.loc[:,:].mean()
# Out:
# 217    143.489286
# 221     29.340079
# 227     87.552778
# 228     -8.155556
# 229    -66.537302
# 230     16.245635
# 232      5.398810
# 233     -1.068254
# dtype: float64

# %%
net_ans=n.loc[:,:].mean()

# %%
net=net_ans/1000
net
# Out:
# 217    0.143489
# 221    0.029340
# 227    0.087553
# 228   -0.008156
# 229   -0.066537
# 230    0.016246
# 232    0.005399
# 233   -0.001068
# dtype: float64

# %%
ad=a.index
ad
# Out:
# Index([217, 221, 227, 228, 229, 230, 232, 233], dtype='int64')

# %%
# df.loc[ad,'net_Change']
